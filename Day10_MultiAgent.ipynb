# %% [markdown]
# <a href="https://colab.research.google.com/github/gangababupokanati/ai-mentor-portfolio/blob/main/Day10_MultiAgent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q "numpy<2.0"
# !pip install -q --upgrade crewai litellm google-generativeai google-genai

# %%
import os, getpass

os.environ["GEMINI_API_KEY"] = getpass.getpass("Enter Gemini API Key: ")

print("API key set")
# Out:
# Enter Gemini API Key: ··········
# API key set

# %%
from crewai import Agent, Task, Crew, Process

print("CrewAI imported successfully")
# Out:
# 06:57:57 - LiteLLM:WARNING: common_utils.py:979 - litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# 06:57:58 - LiteLLM:WARNING: common_utils.py:24 - litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# CrewAI imported successfully

# %%
llm = "gemini/gemini-2.5-flash"

# %%
researcher = Agent(
    role="Placement Researcher",
    goal="Compile concise, factual placement-prep notes for B.Tech students",
    backstory="You are a research analyst who prepares short factual placement briefs in bullet form.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Researcher agent created")
# Out:
# Researcher agent created

# %%
writer = Agent(
    role="Placement Brief Writer",
    goal="Convert research notes into a clean 1-page placement brief in markdown",
    backstory="You write clear student-friendly placement briefs with headings and actionable takeaways.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Writer agent created")
# Out:
# Writer agent created

# %%
research_task = Task(
    description=(
        "Research TCS Digital placement preparation for B.Tech students. "
        "Include hiring process, technical stack, eligibility, recent hiring trends, "
        "and preparation tips. Give 3-5 bullets per section."
    ),
    agent=researcher,
    expected_output=(
        "Markdown bullet list with 5 sections: Hiring Process, Technical Stack, "
        "Eligibility, Recent Hiring Trends, Prep Tips."
    ),
)

print("Research task created")
# Out:
# Research task created

# %%
write_task = Task(
    description=(
        "Using the research notes, produce a 1-page placement brief for B.Tech students. "
        "Use markdown format. Include a 3-line opening hook, 5 clear sections, "
        "and a 3-line closing call-to-action."
    ),
    agent=writer,
    expected_output='1-page markdown brief titled "TCS Digital — Placement Prep Brief".',
)

print("Writer task created")
# Out:
# Writer task created

# %%
crew = Crew(
    agents=[researcher, writer],
    tasks=[research_task, write_task],
    process=Process.sequential,
    verbose=True,
)

print("Crew created successfully")
# Out:
# Crew created successfully

# %%
llm = "gemini/gemini-2.0-flash"

print("Model updated:", llm)
# Out:
# Model updated: gemini/gemini-2.0-flash

# %%
researcher = Agent(
    role="Placement Researcher",
    goal="Compile concise, factual placement-prep notes for B.Tech students",
    backstory="You are a research analyst who prepares short factual placement briefs in bullet form.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

writer = Agent(
    role="Placement Brief Writer",
    goal="Convert research notes into a clean 1-page placement brief in markdown",
    backstory="You write clear student-friendly placement briefs with headings and actionable takeaways.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

crew = Crew(
    agents=[researcher, writer],
    tasks=[research_task, write_task],
    process=Process.sequential,
    verbose=True,
)

print("Crew recreated with new model")
# Out:
# Crew recreated with new model

# %%
result = await crew.kickoff_async()

print("\n\n=== FINAL OUTPUT ===\n")
print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 108cd4e8-d104-4559-8743-f566114ed4d4                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  ID: cea5f494-54e2-4359-aefd-88e3262db311                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here is a placement preparation brief for TCS Digital for B.Tech students:                                     │
# │                                                                                                                 │
# │  ### Hiring Process                                                                                             │
# │                                                                                                                 │
# │  *   **Online Assessment:** Typically includes an advanced aptitude section (verbal, logical, numerical) and a  │
# │  crucial advanced coding section with 2-3 medium to hard-level problems.                                        │
# │  *   **Technical Interview:** Focuses heavily on Data Structures & Algorithms (DSA), projects listed in the     │
# │  resume, core CS fundamentals (OS, DBMS, OOPs, Networking), and in-depth knowledge of preferred programming     │
# │  languages and frameworks.                                                                                      │
# │  *   **Managerial/HR Interview:** Evaluates communication skills, leadership potential, problem-solving         │
# │  approach, career aspirations, teamwork abilities, and cultural fit with TCS values.                            │
# │                                                                                                                 │
# │  ### Technical Stack                                                                                            │
# │                                                                                                                 │
# │  *   **Core Programming:** Strong proficiency in at least one modern language like Java (with Spring Boot) or   │
# │  Python (with Django/Flask), including advanced concepts.                                                       │
# │  *   **Data Structures & Algorithms (DSA):** Expertise in complex DSA concepts and their practical application  │
# │  to optimize solutions.                                                                                         │
# │  *   **Web Technologies:** Experience with full-stack development, including front-end frameworks (e.g.,        │
# │  React, Angular) and back-end technologies (e.g., Node.js, REST APIs).                                          │
# │  *   **Cloud & Databases:** Familiarity with at least one major cloud platform (AWS, Azure, GCP) and            │
# │  experience with both SQL (e.g., MySQL, PostgreSQL) and NoSQL (e.g., MongoDB) databases.                        │
# │  *   **Emerging Technologies:** Basic understanding or project exposure to areas like Machine Learning, AI,     │
# │  IoT, Big Data, or Cybersecurity is highly advantageous.                                                        │
# │                                                                                                                 │
# │  ### Eligibility                                                                                                │
# │                                                                                                                 │
# │  *   **Degree:** Primarily B.Tech/B.E. students from relevant engineering disciplines (CSE, IT, ECE, EEE,       │
# │  etc.).                                                                                                         │
# │  *   **Academic Performance:** Consistent academic record, often requiring a minimum of 60% or 6.0 CGPA         │
# │  throughout 10th, 12th, and B.Tech.                                                                             │
# │  *   **Backlogs:** Generally, no active backlogs are allowed at the time of application or joining.             │
# │  *   **Academic Gap:** Typically permits a maximum of 1-2 years gap in the overall academic career.             │
# │                                                                                                                 │
# │  ### Recent Hiring Trends                                                                                       │
# │                                                                                                                 │
# │  *   **Increased Focus on Specialization:** Digital roles are increasingly targeting candidates with specific,  │
# │  in-depth skills in areas like AI/ML, Cloud Engineering, Cybersecurity, Data Science, or full-stack             │
# │  development.                                                                                                   │
# │  *   **Emphasis on Practical Skills:** Strong preference for candidates who can demonstrate their               │
# │  problem-solving and coding abilities through competitive programming platforms and real-world projects.        │
# │  *   **Higher Skill Bar:** Expectations for problem-solving, DSA proficiency, and advanced technical knowledge  │
# │  are significantly higher compared to TCS Ninja roles.                                                          │
# │  *   **Engagement through Contests:** TCS actively identifies talent through hackathons, coding challenges      │
# │  (e.g., CodeVita, InfyTQ), and specialized hiring drives for Digital roles.                                     │
# │  *   **Demand for Innovation:** Candidates who can showcase innovative thinking and a keen interest in          │
# │  emerging technologies are highly valued.                                                                       │
# │                                                                                                                 │
# │  ### Prep Tips                                                                                                  │
# │                                                                                                                 │
# │  *   **Master DSA:** Dedicate significant time to practicing a wide range of Data Structures and Algorithms     │
# │  problems, focusing on medium to hard levels on platforms like LeetCode, HackerRank, and GeeksforGeeks.         │
# │  *   **Deep Dive into a Core Language:** Choose one programming language (Java, Python, C++) and become truly   │
# │  proficient, understanding its advanced features, frameworks, and best practices.                               │
# │  *   **Build Strong Projects:** Develop 2-3 substantial, well-documented projects that demonstrate your         │
# │  technical skills, problem-solving abilities, and practical application of technologies.                        │
# │  *   **Strengthen CS Fundamentals:** Thoroughly revise core Computer Science concepts like Operating Systems,   │
# │  Database Management Systems, Object-Oriented Programming (OOPs), and Computer Networks.                        │
# │  *   **Practice Mock Interviews:** Regularly participate in mock technical and HR interviews to improve your    │
# │  articulation, coding under pressure, and ability to discuss projects and behavioral questions confidently.     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  ID: 01bb4813-f7b9-4367-9798-311492c82e03                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Task: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:Google Gemini API error: 503 - This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.
# An unknown error occurred. Please check the details below.
# Error details: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# ERROR:crewai.flow.flow:Error executing listener call_llm_and_parse: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: Google Gemini API error: 503 - This model is currently experiencing high demand. Spikes in demand are   │
# │  usually temporary. Please try again later.                                                                     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# An unknown error occurred. Please check the details below.
# Error details: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Task: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:Google Gemini API error: 503 - This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.
# An unknown error occurred. Please check the details below.
# Error details: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# ERROR:crewai.flow.flow:Error executing listener call_llm_and_parse: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: Google Gemini API error: 503 - This model is currently experiencing high demand. Spikes in demand are   │
# │  usually temporary. Please try again later.                                                                     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# An unknown error occurred. Please check the details below.
# Error details: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Task: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # TCS Digital — Placement Prep Brief                                                                           │
# │                                                                                                                 │
# │  Aiming for a career at the forefront of digital innovation?                                                    │
# │  TCS Digital offers B.Tech students a gateway to advanced tech roles with higher responsibilities and           │
# │  cutting-edge projects.                                                                                         │
# │  Prepare to elevate your skills and secure your spot in this competitive program!                               │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### 1. The Road to TCS Digital (Hiring Process)                                                                │
# │                                                                                                                 │
# │  The selection process is rigorous, designed to identify top technical talent:                                  │
# │                                                                                                                 │
# │  *   **Online Assessment:** Expect an advanced aptitude section combined with a crucial advanced coding         │
# │  section featuring 2-3 medium to hard-level problems.                                                           │
# │  *   **Technical Interview:** A deep dive into Data Structures & Algorithms (DSA), your resume projects, core   │
# │  CS fundamentals (OS, DBMS, OOPs, Networking), and in-depth knowledge of your preferred programming languages   │
# │  and frameworks.                                                                                                │
# │  *   **Managerial/HR Interview:** Evaluates your communication skills, leadership potential, problem-solving    │
# │  approach, career aspirations, teamwork abilities, and cultural fit within TCS.                                 │
# │                                                                                                                 │
# │  ### 2. Your Digital Skillset (Technical Stack)                                                                 │
# │                                                                                                                 │
# │  TCS Digital roles demand specialized and deep technical expertise:                                             │
# │                                                                                                                 │
# │  *   **Core Programming:** Strong proficiency in at least one modern language like Java (with Spring Boot) or   │
# │  Python (with Django/Flask), including advanced concepts.                                                       │
# │  *   **Data Structures & Algorithms (DSA):** Expertise in complex DSA concepts and their practical application  │
# │  to optimize solutions.                                                                                         │
# │  *   **Web Technologies:** Experience with full-stack development, including front-end frameworks (e.g.,        │
# │  React, Angular) and back-end technologies (e.g., Node.js, REST APIs).                                          │
# │  *   **Cloud & Databases:** Familiarity with at least one major cloud platform (AWS, Azure, GCP) and            │
# │  experience with both SQL (e.g., MySQL, PostgreSQL) and NoSQL (e.g., MongoDB) databases.                        │
# │  *   **Emerging Technologies:** Basic understanding or project exposure to areas like Machine Learning, AI,     │
# │  IoT, Big Data, or Cybersecurity is highly advantageous.                                                        │
# │                                                                                                                 │
# │  ### 3. Are You Eligible? (Eligibility)                                                                         │
# │                                                                                                                 │
# │  Ensure you meet the fundamental criteria before applying:                                                      │
# │                                                                                                                 │
# │  *   **Degree:** Primarily B.Tech/B.E. students from relevant engineering disciplines (CSE, IT, ECE, EEE,       │
# │  etc.).                                                                                                         │
# │  *   **Academic Performance:** Consistent academic record, often requiring a minimum of 60% or 6.0 CGPA         │
# │  throughout 10th, 12th, and B.Tech.                                                                             │
# │  *   **Backlogs:** Generally, no active backlogs are allowed at the time of application or joining.             │
# │  *   **Academic Gap:** Typically permits a maximum of 1-2 years gap in the overall academic career.             │
# │                                                                                                                 │
# │  ### 4. What TCS Digital Looks For (Recent Hiring Trends)                                                       │
# │                                                                                                                 │
# │  Understanding current trends can help tailor your preparation:                                                 │
# │                                                                                                                 │
# │  *   **Increased Focus on Specialization:** Digital roles target candidates with specific, in-depth skills in   │
# │  areas like AI/ML, Cloud Engineering, Cybersecurity, Data Science, or full-stack development.                   │
# │  *   **Emphasis on Practical Skills:** Strong preference for candidates who demonstrate problem-solving and     │
# │  coding abilities through competitive programming and real-world projects.                                      │
# │  *   **Higher Skill Bar:** Expectations for problem-solving, DSA proficiency, and advanced technical knowledge  │
# │  are significantly higher compared to TCS Ninja roles.                                                          │
# │  *   **Engagement through Contests:** TCS actively identifies talent through hackathons, coding challenges      │
# │  (e.g., CodeVita), and specialized hiring drives.                                                               │
# │  *   **Demand for Innovation:** Candidates showcasing innovative thinking and a keen interest in emerging       │
# │  technologies are highly valued.                                                                                │
# │                                                                                                                 │
# │  ### 5. Your Action Plan (Prep Tips)                                                                            │
# │                                                                                                                 │
# │  Strategize your preparation for success:                                                                       │
# │                                                                                                                 │
# │  *   **Master DSA:** Dedicate significant time to practicing a wide range of Data Structures and Algorithms     │
# │  problems, focusing on medium to hard levels on platforms like LeetCode, HackerRank, and GeeksforGeeks.         │
# │  *   **Deep Dive into a Core Language:** Choose one programming language (Java, Python, C++) and become truly   │
# │  proficient, understanding its advanced features, frameworks, and best practices.                               │
# │  *   **Build Strong Projects:** Develop 2-3 substantial, well-documented projects that demonstrate your         │
# │  technical skills, problem-solving abilities, and practical application of technologies.                        │
# │  *   **Strengthen CS Fundamentals:** Thoroughly revise core Computer Science concepts like Operating Systems,   │
# │  Database Management Systems, Object-Oriented Programming (OOPs), and Computer Networks.                        │
# │  *   **Practice Mock Interviews:** Regularly participate in mock technical and HR interviews to improve your    │
# │  articulation, coding under pressure, and ability to discuss projects and behavioral questions confidently.     │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  TCS Digital is your chance to shine in the evolving tech landscape.                                            │
# │  Start preparing now, hone your expertise, and build a portfolio that stands out.                               │
# │  Your journey to a transformative career begins with robust preparation!                                        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === FINAL OUTPUT ===
#
# # TCS Digital — Placement Prep Brief
#
# Aiming for a career at the forefront of digital innovation?
# TCS Digital offers B.Tech students a gateway to advanced tech roles with higher responsibilities and cutting-edge projects.
# Prepare to elevate your skills and secure your spot in this competitive program!
#
# ---
#
# ### 1. The Road to TCS Digital (Hiring Process)
#
# The selection process is rigorous, designed to identify top technical talent:
#
# *   **Online Assessment:** Expect an advanced aptitude section combined with a crucial advanced coding section featuring 2-3 medium to hard-level problems.
# *   **Technical Interview:** A deep dive into Data Structures & Algorithms (DSA), your resume projects, core CS fundamentals (OS, DBMS, OOPs, Networking), and in-depth knowledge of your preferred programming languages and frameworks.
# *   **Managerial/HR Interview:** Evaluates your communication skills, leadership potential, problem-solving approach, career aspirations, teamwork abilities, and cultural fit within TCS.
#
# ### 2. Your Digital Skillset (Technical Stack)
#
# TCS Digital roles demand specialized and deep technical expertise:
#
# *   **Core Programming:** Strong proficiency in at least one modern language like Java (with Spring Boot) or Python (with Django/Flask), including advanced concepts.
# *   **Data Structures & Algorithms (DSA):** Expertise in complex DSA concepts and their practical application to optimize solutions.
# *   **Web Technologies:** Experience with full-stack development, including front-end frameworks (e.g., React, Angular) and back-end technologies (e.g., Node.js, REST APIs).
# *   **Cloud & Databases:** Familiarity with at least one major cloud platform (AWS, Azure, GCP) and experience with both SQL (e.g., MySQL, PostgreSQL) and NoSQL (e.g., MongoDB) databases.
# *   **Emerging Technologies:** Basic understanding or project exposure to areas like Machine Learning, AI, IoT, Big Data, or Cybersecurity is highly advantageous.
#
# ### 3. Are You Eligible? (Eligibility)
#
# Ensure you meet the fundamental criteria before applying:
#
# *   **Degree:** Primarily B.Tech/B.E. students from relevant engineering disciplines (CSE, IT, ECE, EEE, etc.).
# *   **Academic Performance:** Consistent academic record, often requiring a minimum of 60% or 6.0 CGPA throughout 10th, 12th, and B.Tech.
# *   **Backlogs:** Generally, no active backlogs are allowed at the time of application or joining.
# *   **Academic Gap:** Typically permits a maximum of 1-2 years gap in the overall academic career.
#
# ### 4. What TCS Digital Looks For (Recent Hiring Trends)
#
# Understanding current trends can help tailor your preparation:
#
# *   **Increased Focus on Specialization:** Digital roles target candidates with specific, in-depth skills in areas like AI/ML, Cloud Engineering, Cybersecurity, Data Science, or full-stack development.
# *   **Emphasis on Practical Skills:** Strong preference for candidates who demonstrate problem-solving and coding abilities through competitive programming and real-world projects.
# *   **Higher Skill Bar:** Expectations for problem-solving, DSA proficiency, and advanced technical knowledge are significantly higher compared to TCS Ninja roles.
# *   **Engagement through Contests:** TCS actively identifies talent through hackathons, coding challenges (e.g., CodeVita), and specialized hiring drives.
# *   **Demand for Innovation:** Candidates showcasing innovative thinking and a keen interest in emerging technologies are highly valued.
#
# ### 5. Your Action Plan (Prep Tips)
#
# Strategize your preparation for success:
#
# *   **Master DSA:** Dedicate significant time to practicing a wide range of Data Structures and Algorithms problems, focusing on medium to hard levels on platforms like LeetCode, HackerRank, and GeeksforGeeks.
# *   **Deep Dive into a Core Language:** Choose one programming language (Java, Python, C++) and become truly proficient, understanding its advanced features, frameworks, and best practices.
# *   **Build Strong Projects:** Develop 2-3 substantial, well-documented projects that demonstrate your technical skills, problem-solving abilities, and practical application of technologies.
# *   **Strengthen CS Fundamentals:** Thoroughly revise core Computer Science concepts like Operating Systems, Database Management Systems, Object-Oriented Programming (OOPs), and Computer Networks.
# *   **Practice Mock Interviews:** Regularly participate in mock technical and HR interviews to improve your articulation, coding under pressure, and ability to discuss projects and behavioral questions confidently.
#
# ---
#
# TCS Digital is your chance to shine in the evolving tech landscape.
# Start preparing now, hone your expertise, and build a portfolio that stands out.
# Your journey to a transformative career begins with robust preparation!
#
#
# ╭────────────────────────── Tracing Preference Saved ──────────────────────────╮
# │                                                                              │
# │  Info: Tracing has been disabled.                                            │
# │                                                                              │
# │  Your preference has been saved. Future Crew/Flow executions will not        │
# │  collect traces.                                                             │
# │                                                                              │
# │  To enable tracing later, do any one of these:                               │
# │  • Set tracing=True in your Crew/Flow code                                   │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file               │
# │  • Run: crewai traces enable                                                 │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯

# %%
import pathlib

pathlib.Path("day10_lab10a_transcript.txt").write_text(str(result))

print("Saved: day10_lab10a_transcript.txt")
print("Characters:", len(str(result)))
# Out:
# Saved: day10_lab10a_transcript.txt
# Characters: 4774

# %%
try:
    for i, output in enumerate(result.tasks_output):
        print(f"\n=== Task {i+1} Output ===")
        print(str(output)[:800])
except Exception:
    print("Task outputs not available in this CrewAI version.")
    print("Final result saved successfully.")
# Out:
# === Task 1 Output ===
# Here is a placement preparation brief for TCS Digital for B.Tech students:
#
# ### Hiring Process
#
# *   **Online Assessment:** Typically includes an advanced aptitude section (verbal, logical, numerical) and a crucial advanced coding section with 2-3 medium to hard-level problems.
# *   **Technical Interview:** Focuses heavily on Data Structures & Algorithms (DSA), projects listed in the resume, core CS fundamentals (OS, DBMS, OOPs, Networking), and in-depth knowledge of preferred programming languages and frameworks.
# *   **Managerial/HR Interview:** Evaluates communication skills, leadership potential, problem-solving approach, career aspirations, teamwork abilities, and cultural fit with TCS values.
#
# ### Technical Stack
#
# *   **Core Programming:** Strong proficiency in at least one modern langu
#
# === Task 2 Output ===
# # TCS Digital — Placement Prep Brief
#
# Aiming for a career at the forefront of digital innovation?
# TCS Digital offers B.Tech students a gateway to advanced tech roles with higher responsibilities and cutting-edge projects.
# Prepare to elevate your skills and secure your spot in this competitive program!
#
# ---
#
# ### 1. The Road to TCS Digital (Hiring Process)
#
# The selection process is rigorous, designed to identify top technical talent:
#
# *   **Online Assessment:** Expect an advanced aptitude section combined with a crucial advanced coding section featuring 2-3 medium to hard-level problems.
# *   **Technical Interview:** A deep dive into Data Structures & Algorithms (DSA), your resume projects, core CS fundamentals (OS, DBMS, OOPs, Networking), and in-depth knowledge of your preferred programming

# %%
markdown_content = str(result)

with open("tcs_digital_brief.md", "w", encoding="utf-8") as f:
    f.write(markdown_content)

print("Markdown file created successfully: tcs_digital_brief.md")
# Out:
# Markdown file created successfully: tcs_digital_brief.md

# %%
from google.colab import files

files.download("tcs_digital_brief.md")

# %%
with open("tcs_digital_brief.md", "r", encoding="utf-8") as f:
    print(f.read()[:2000])
# Out:
# # TCS Digital — Placement Prep Brief
#
# Aiming for a career at the forefront of digital innovation?
# TCS Digital offers B.Tech students a gateway to advanced tech roles with higher responsibilities and cutting-edge projects.
# Prepare to elevate your skills and secure your spot in this competitive program!
#
# ---
#
# ### 1. The Road to TCS Digital (Hiring Process)
#
# The selection process is rigorous, designed to identify top technical talent:
#
# *   **Online Assessment:** Expect an advanced aptitude section combined with a crucial advanced coding section featuring 2-3 medium to hard-level problems.
# *   **Technical Interview:** A deep dive into Data Structures & Algorithms (DSA), your resume projects, core CS fundamentals (OS, DBMS, OOPs, Networking), and in-depth knowledge of your preferred programming languages and frameworks.
# *   **Managerial/HR Interview:** Evaluates your communication skills, leadership potential, problem-solving approach, career aspirations, teamwork abilities, and cultural fit within TCS.
#
# ### 2. Your Digital Skillset (Technical Stack)
#
# TCS Digital roles demand specialized and deep technical expertise:
#
# *   **Core Programming:** Strong proficiency in at least one modern language like Java (with Spring Boot) or Python (with Django/Flask), including advanced concepts.
# *   **Data Structures & Algorithms (DSA):** Expertise in complex DSA concepts and their practical application to optimize solutions.
# *   **Web Technologies:** Experience with full-stack development, including front-end frameworks (e.g., React, Angular) and back-end technologies (e.g., Node.js, REST APIs).
# *   **Cloud & Databases:** Familiarity with at least one major cloud platform (AWS, Azure, GCP) and experience with both SQL (e.g., MySQL, PostgreSQL) and NoSQL (e.g., MongoDB) databases.
# *   **Emerging Technologies:** Basic understanding or project exposure to areas like Machine Learning, AI, IoT, Big Data, or Cybersecurity is highly advantageous.
#
# ### 3. Are You Eligible? (Eligibility)
#
# Ensu
